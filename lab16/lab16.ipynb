# %% [markdown]
#  <font size=6> **实验16 现代循环神经网络**</font>

# %% [markdown]
# * 理解GRU要解决问题、算法思路，并能熟练运用；
# * 理解LSTM要解决问题、算法思路，并能熟练运用；
# * 理解深度循环神经网络的基本结构和简洁实现；
# * 理解双向循环神经网络(BiLSTM)的基本思路、适用范围；
# * 了解机器翻译与数据集的基本流程。

# %% [markdown]
# **(实验报告提交题)**  lab_16_4目录中spider.ipynb程序是根据https://zhuanlan.zhihu.com/p/597957245 站点代码改编的(原url无效)，其功能是爬取李白诗词并保存到libai.txt.文件中，请据此使用LSTM实现李白诗词生成的功能。

# %% [markdown]
# # 导入库

# %%
import numpy as np
import torch
import torch.nn as nn
from torch.nn.utils.rnn import pack_padded_sequence, pad_packed_sequence
import torch.optim as optim
import numpy as np
import random

# %% [markdown]
# # 数据加载和处理

# %% [markdown]
# ## 加载数据

# %%
with open('libai.txt', 'r', encoding='utf8') as file:
    content = file.read().replace('\n', '')
# print(content.replace('\n', ''))
chars = list(set(content))
print(chars)
n_chars = len(chars)
print(n_chars)
# 字符与对应数字标记
char_indices = dict((c, i) for i, c in enumerate(chars))
print(char_indices)
# 数字标记与对应的字符
indices_char = dict((i, c) for i, c in enumerate(chars))
print(indices_char)

maxlen = 20
step = 3
sentences = []
next_chars = []
for i in range(0, len(content) - maxlen, step):
    sentences.append(content[i: i+maxlen])
    next_chars.append(content[i+maxlen])
# Out:
# ['脱', '浩', '五', '感', '许', '是', '离', '载', '罢', '固', '笔', '归', '旃', '危', '予', '招', '造', '童', '迫', '羲', '散', '虎', '忘', '俱', '保', '略', '轮', '促', '奴', '蜍', '蔓', '馔', '及', '烛', '僧', '帝', '客', '何', '辰', '肆', '亥', '却', '阶', '乎', '声', '啼', '御', '没', '徒', '荡', '礼', '宾', '雅', '膺', '携', '代', '冠', '骨', '湾', '翠', '烹', '居', '帏', '个', '响', '城', '妒', '卢', '生', '身', '俊', '水', '至', '歇', '掷', '游', '缺', '霸', '鸾', '簸', '所', '漱', '敢', '殊', '管', '鸟', '两', '田', '仁', '苔', '翁', '宣', '避', '迁', '烜', '解', '建', '杖', '溪', '杯', '谣', '隗', '容', '徂', '户', '试', '隘', '殿', '道', '洲', '炎', '泪', '猱', '块', '赵', '半', '夏', '压', '吐', '句', '忧', '午', '入', '虏', '栈', '寞', '凉', '怀', '驻', '始', '湿', '焚', '桀', '常', '施', '求', '岭', '堆', '彩', '窈', '黄', '涂', '羞', '肯', '罗', '今', '盛', '丝', '骠', '赐', '夙', '其', '发', '寻', '尔', '泉', '络', '久', '左', '珑', '征', '尺', '雉', '亦', '松', '望', '恨', '菱', '适', '西', '玉', '残', '幽', '双', '娱', '识', '当', '喜', '兹', '胁', '桥', '徘', '清', '匹', '悲', '逸', '题', '市', '听', '萏', '京', '坐', '年', '旧', '弃', '布', '县', '妇', '石', '甚', '吴', '沽', '夷', '店', '期', '必', '；', '渚', '巾', '醢', '竟', '北', '魂', '挂', '谠', '忌', '澜', '一', '掩', '铄', '疾', '丘', '敖', '倘', '抚', '枯', '旄', '蜀', '凰', '毛', '碎', '萧', '浪', '庐', '嫁', '莲', '啄', '秉', '微', '陇', '俯', '螯', '岑', '耐', '嶂', '萝', '扫', '舟', '召', '边', '潭', '讵', '修', '况', '险', '共', '里', '风', '烈', '攀', '文', '热', '织', '酌', '鼓', '阴', '侯', '愧', '桂', '毅', '烟', '令', '瀛', '衔', '赧', '肃', '仙', '涉', '朝', '他', '初', '土', '怨', '假', '之', '昨', '迢', '咳', '陪', '步', '场', '空', '糟', '无', '暂', '疑', '园', '自', '家', '静', '稀', '谁', '吠', '闻', '皆', '舞', '零', '时', '只', '说', '干', '我', '置', '放', '才', '渡', '辛', '专', '昭', '机', '钩', '陵', '巫', '荷', '昊', '辈', '灭', '已', '、', '殒', '广', '勾', '控', '英', '龄', '席', '湖', '凤', '傥', '莫', '埃', '夕', '行', '低', '故', '邯', '山', '诺', '在', '手', '树', '与', '迷', '赦', '贵', '尝', '三', '义', '肥', '众', '圆', '托', '著', '秩', '阁', '腾', '星', '聚', '者', '匈', '掬', '事', '穷', '帆', '揽', '存', '公', '襟', '茫', '歧', '紫', '预', '平', '忽', '烦', '侬', '中', '急', '兀', '驾', '九', '而', '仰', '阳', '骑', '营', '师', '坠', '任', '瀑', '陶', '尽', '聊', '桑', '作', '漫', '列', '兴', '仍', '楠', '妆', '标', '咸', '梨', '部', '投', '务', '！', '渠', '际', '陆', '鸥', '额', '槌', '戈', '层', '直', '乃', '枉', '嫦', '亲', '涸', '遇', '侠', '峨', '鲸', '愁', '岸', '并', '绮', '扪', '君', '思', '滟', '救', '秋', '想', '邑', '士', '绊', '南', '野', '神', '乌', '圣', '向', '鱼', '依', '皎', '锦', '岂', '雨', '涨', '频', '盘', '晨', '宴', '昆', '庭', '骧', '劝', '得', '火', '饮', '八', '视', '深', '六', '池', '程', '鹤', '犬', '突', '学', '拨', '嬴', '还', '森', '赊', '疏', '汝', '冥', '秾', '误', '赏', '黍', '铁', '班', '开', '借', '？', '惧', '瑟', '梯', '迎', '哭', '咏', '展', '帐', '商', '折', '弹', '宠', '夫', '羌', '罪', '精', '敬', '良', '洞', '黛', '且', '霹', '罝', '镜', '佩', '蔡', '箸', '射', '再', '销', '窕', '练', '柳', '可', '似', '鹧', '眼', '玄', '凄', '质', '丹', '踏', '调', '灰', '服', '爱', '十', '传', '溃', '伫', '永', '立', '高', '功', '宿', '挟', '戏', '章', '耳', '越', '觞', '材', '绝', '钦', '瑶', '子', '屋', '漾', '遗', '床', '正', '有', '欢', '蒿', '网', '四', '萨', '卿', '雕', '梦', '下', '扉', '辉', '参', '烂', '訇', '巴', '恣', '戍', '蛇', '度', '谑', '用', '变', '转', '退', '顶', '官', '老', '川', '艳', '受', '湍', '济', '力', '碗', '负', '霞', '璧', '卫', '岩', '落', '吟', '宁', '狼', '女', '亭', '历', '根', '卷', '晔', '隐', '通', '欺', '车', '纷', '寥', '颇', '痕', '血', '江', '进', '弟', '淮', '候', '昼', '馆', '蚀', '蓬', '纳', '跨', '逻', '破', '雁', '狗', '晶', '带', '旅', '：', '翻', '片', '碧', '恍', '战', '叶', '白', '钱', '画', '李', '眉', '含', '荣', '羽', '回', '荒', '日', '色', '衣', '能', '筵', '香', '遭', '觉', '灞', '凫', '昔', '闲', '谪', '哉', '摘', '曳', '黑', '尘', '牵', '伦', '窗', '叔', '斩', '长', '巉', '袒', '噫', '飞', '倒', '夜', '裘', '谓', '若', '歌', '秦', '凝', '豺', '腰', '酣', '孟', '情', '字', '汉', '恩', '槛', '乱', '摇', '叹', '规', '国', '景', '宵', '驱', '黯', '雄', '处', '复', '鹏', '兮', '死', '雳', '蚕', '遂', '泥', '朗', '劳', '沙', '乐', '枻', '引', '失', '懒', '醉', '间', '兵', '蝴', '恤', '凿', '睹', '逢', '鋋', '侍', '林', '榭', '那', '须', '咆', '邕', '钟', '纱', '沾', '剪', '轩', '鹇', '傍', ' ', '军', '酒', '炉', '记', '猿', '滪', '名', '剧', '趣', '击', '妻', '蝶', '值', '裳', '袜', '纵', '霓', '房', '唾', '吾', '访', '磨', '姥', '金', '最', '舒', '棠', '墟', '外', '余', '然', '月', '邈', '过', '信', '鸯', '贾', '露', ...
# 1472
# {'脱': 0, '浩': 1, '五': 2, '感': 3, '许': 4, '是': 5, '离': 6, '载': 7, '罢': 8, '固': 9, '笔': 10, '归': 11, '旃': 12, '危': 13, '予': 14, '招': 15, '造': 16, '童': 17, '迫': 18, '羲': 19, '散': 20, '虎': 21, '忘': 22, '俱': 23, '保': 24, '略': 25, '轮': 26, '促': 27, '奴': 28, '蜍': 29, '蔓': 30, '馔': 31, '及': 32, '烛': 33, '僧': 34, '帝': 35, '客': 36, '何': 37, '辰': 38, '肆': 39, '亥': 40, '却': 41, '阶': 42, '乎': 43, '声': 44, '啼': 45, '御': 46, '没': 47, '徒': 48, '荡': 49, '礼': 50, '宾': 51, '雅': 52, '膺': 53, '携': 54, '代': 55, '冠': 56, '骨': 57, '湾': 58, '翠': 59, '烹': 60, '居': 61, '帏': 62, '个': 63, '响': 64, '城': 65, '妒': 66, '卢': 67, '生': 68, '身': 69, '俊': 70, '水': 71, '至': 72, '歇': 73, '掷': 74, '游': 75, '缺': 76, '霸': 77, '鸾': 78, '簸': 79, '所': 80, '漱': 81, '敢': 82, '殊': 83, '管': 84, '鸟': 85, '两': 86, '田': 87, '仁': 88, '苔': 89, '翁': 90, '宣': 91, '避': 92, '迁': 93, '烜': 94, '解': 95, '建': 96, '杖': 97, '溪': 98, '杯': 99, '谣': 100, '隗': 101, '容': 102, '徂': 103, '户': 104, '试': 105, '隘': 106, '殿': 107, '道': 108, '洲': 109, '炎': 110, '泪': 111, '猱': 112, '块': 113, '赵': 114, '半': 115, '夏': 116, '压': 117, '吐': 118, '句': 119, '忧': 120, '午': 121, '入': 122, '虏': 123, '栈': 124, '寞': 125, '凉': 126, '怀': 127, '驻': 128, '始': 129, '湿': 130, '焚': 131, '桀': 132, '常': 133, '施': 134, '求': 135, '岭': 136, '堆': 137, '彩': 138, '窈': 139, '黄': 140, '涂': 141, '羞': 142, '肯': 143, '罗': 144, '今': 145, '盛': 146, '丝': 147, '骠': 148, '赐': 149, '夙': 150, '其': 151, '发': 152, '寻': 153, '尔': 154, '泉': 155, '络': 156, '久': 157, '左': 158, '珑': 159, '征': 160, '尺': 161, '雉': 162, '亦': 163, '松': 164, '望': 165, '恨': 166, '菱': 167, '适': 168, '西': 169, '玉': 170, '残': 171, '幽': 172, '双': 173, '娱': 174, '识': 175, '当': 176, '喜': 177, '兹': 178, '胁': 179, '桥': 180, '徘': 181, '清': 182, '匹': 183, '悲': 184, '逸': 185, '题': 186, '市': 187, '听': 188, '萏': 189, '京': 190, '坐': 191, '年': 192, '旧': 193, '弃': 194, '布': 195, '县': 196, '妇': 197, '石': 198, '甚': 199, '吴': 200, '沽': 201, '夷': 202, '店': 203, '期': 204, '必': 205, '；': 206, '渚': 207, '巾': 208, '醢': 209, '竟': 210, '北': 211, '魂': 212, '挂': 213, '谠': 214, '忌': 215, '澜': 216, '一': 217, '掩': 218, '铄': 219, '疾': 220, '丘': 221, '敖': 222, '倘': 223, '抚': 224, '枯': 225, '旄': 226, '蜀': 227, '凰': 228, '毛': 229, '碎': 230, '萧': 231, '浪': 232, '庐': 233, '嫁': 234, '莲': 235, '啄': 236, '秉': 237, '微': 238, '陇': 239, '俯': 240, '螯': 241, '岑': 242, '耐': 243, '嶂': 244, '萝': 245, '扫': 246, '舟': 247, '召': 248, '边': 249, '潭': 250, '讵': 251, '修': 252, '况': 253, '险': 254, '共': 255, '里': 256, '风': 257, '烈': 258, '攀': 259, '文': 260, '热': 261, '织': 262, '酌': 263, '鼓': 264, '阴': 265, '侯': 266, '愧': 267, '桂': 268, '毅': 269, '烟': 270, '令': 271, '瀛': 272, '衔': 273, '赧': 274, '肃': 275, '仙': 276, '涉': 277, '朝': 278, '他': 279, '初': 280, '土': 281, '怨': 282, '假': 283, '之': 284, '昨': 285, '迢': 286, '咳': 287, '陪': 288, '步': 289, '场': 290, '空': 291, '糟': 292, '无': 293, '暂': 294, '疑': 295, '园': 296, '自': 297, '家': 298, '静': 299, '稀': 300, '谁': 301, '吠': 302, '闻': 303, '皆': 304, '舞': 305, '零': 306, '时': 307, '只': 308, '说': 309, '干': 310, '我': 311, '置': 312, '放': 313, '才': 314, '渡': 315, '辛': 316, '专': 317, '昭': 318, '机': 319, '钩': 320, '陵': 321, '巫': 322, '荷': 323, '昊': 324, '辈': 325, '灭': 326, '已': 327, '、': 328, '殒': 329, '广': 330, '勾': 331, '控': 332, '英': 333, '龄': 334, '席': 335, '湖': 336, '凤': 337, '傥': 338, '莫': 339, '埃': 340, '夕': 341, '行': 342, '低': 343, '故': 344, '邯': 345, '山': 346, '诺': 347, '在': 348, '手': 349, '树': 350, '与': 351, '迷': 352, '赦': 353, '贵': 354, '尝': 355, '三': 356, '义': 357, '肥': 358, '众': 359, '圆': 360, '托': 361, '著': 362, '秩': 363, '阁': 364, '腾': 365, '星': 366, '聚': 367, '者': 368, '匈': 369, '掬': 370, '事': 371, '穷': 372, '帆': 373, '揽': 374, '存': 375, '公': 376, '襟': 377, '茫': 378, '歧': 379, '紫': 380, '预': 381, '平': 382, '忽': 383, '烦': 384, '侬': 385, '中': 386, '急': 387, '兀': 388, '驾': 389, '九': 390, '而': 391, '仰': 392, '阳': 393, '骑': 394, '营': 395, '师': 396, '坠': 397, '任': 398, '瀑': 399, '陶': 400, '尽': 401, '聊': 402, '桑': 403, '作': 404, '漫': 405, '列': 406, '兴': 407, '仍': 408, '楠': 409, '妆': 410, ...
# {0: '脱', 1: '浩', 2: '五', 3: '感', 4: '许', 5: '是', 6: '离', 7: '载', 8: '罢', 9: '固', 10: '笔', 11: '归', 12: '旃', 13: '危', 14: '予', 15: '招', 16: '造', 17: '童', 18: '迫', 19: '羲', 20: '散', 21: '虎', 22: '忘', 23: '俱', 24: '保', 25: '略', 26: '轮', 27: '促', 28: '奴', 29: '蜍', 30: '蔓', 31: '馔', 32: '及', 33: '烛', 34: '僧', 35: '帝', 36: '客', 37: '何', 38: '辰', 39: '肆', 40: '亥', 41: '却', 42: '阶', 43: '乎', 44: '声', 45: '啼', 46: '御', 47: '没', 48: '徒', 49: '荡', 50: '礼', 51: '宾', 52: '雅', 53: '膺', 54: '携', 55: '代', 56: '冠', 57: '骨', 58: '湾', 59: '翠', 60: '烹', 61: '居', 62: '帏', 63: '个', 64: '响', 65: '城', 66: '妒', 67: '卢', 68: '生', 69: '身', 70: '俊', 71: '水', 72: '至', 73: '歇', 74: '掷', 75: '游', 76: '缺', 77: '霸', 78: '鸾', 79: '簸', 80: '所', 81: '漱', 82: '敢', 83: '殊', 84: '管', 85: '鸟', 86: '两', 87: '田', 88: '仁', 89: '苔', 90: '翁', 91: '宣', 92: '避', 93: '迁', 94: '烜', 95: '解', 96: '建', 97: '杖', 98: '溪', 99: '杯', 100: '谣', 101: '隗', 102: '容', 103: '徂', 104: '户', 105: '试', 106: '隘', 107: '殿', 108: '道', 109: '洲', 110: '炎', 111: '泪', 112: '猱', 113: '块', 114: '赵', 115: '半', 116: '夏', 117: '压', 118: '吐', 119: '句', 120: '忧', 121: '午', 122: '入', 123: '虏', 124: '栈', 125: '寞', 126: '凉', 127: '怀', 128: '驻', 129: '始', 130: '湿', 131: '焚', 132: '桀', 133: '常', 134: '施', 135: '求', 136: '岭', 137: '堆', 138: '彩', 139: '窈', 140: '黄', 141: '涂', 142: '羞', 143: '肯', 144: '罗', 145: '今', 146: '盛', 147: '丝', 148: '骠', 149: '赐', 150: '夙', 151: '其', 152: '发', 153: '寻', 154: '尔', 155: '泉', 156: '络', 157: '久', 158: '左', 159: '珑', 160: '征', 161: '尺', 162: '雉', 163: '亦', 164: '松', 165: '望', 166: '恨', 167: '菱', 168: '适', 169: '西', 170: '玉', 171: '残', 172: '幽', 173: '双', 174: '娱', 175: '识', 176: '当', 177: '喜', 178: '兹', 179: '胁', 180: '桥', 181: '徘', 182: '清', 183: '匹', 184: '悲', 185: '逸', 186: '题', 187: '市', 188: '听', 189: '萏', 190: '京', 191: '坐', 192: '年', 193: '旧', 194: '弃', 195: '布', 196: '县', 197: '妇', 198: '石', 199: '甚', 200: '吴', 201: '沽', 202: '夷', 203: '店', 204: '期', 205: '必', 206: '；', 207: '渚', 208: '巾', 209: '醢', 210: '竟', 211: '北', 212: '魂', 213: '挂', 214: '谠', 215: '忌', 216: '澜', 217: '一', 218: '掩', 219: '铄', 220: '疾', 221: '丘', 222: '敖', 223: '倘', 224: '抚', 225: '枯', 226: '旄', 227: '蜀', 228: '凰', 229: '毛', 230: '碎', 231: '萧', 232: '浪', 233: '庐', 234: '嫁', 235: '莲', 236: '啄', 237: '秉', 238: '微', 239: '陇', 240: '俯', 241: '螯', 242: '岑', 243: '耐', 244: '嶂', 245: '萝', 246: '扫', 247: '舟', 248: '召', 249: '边', 250: '潭', 251: '讵', 252: '修', 253: '况', 254: '险', 255: '共', 256: '里', 257: '风', 258: '烈', 259: '攀', 260: '文', 261: '热', 262: '织', 263: '酌', 264: '鼓', 265: '阴', 266: '侯', 267: '愧', 268: '桂', 269: '毅', 270: '烟', 271: '令', 272: '瀛', 273: '衔', 274: '赧', 275: '肃', 276: '仙', 277: '涉', 278: '朝', 279: '他', 280: '初', 281: '土', 282: '怨', 283: '假', 284: '之', 285: '昨', 286: '迢', 287: '咳', 288: '陪', 289: '步', 290: '场', 291: '空', 292: '糟', 293: '无', 294: '暂', 295: '疑', 296: '园', 297: '自', 298: '家', 299: '静', 300: '稀', 301: '谁', 302: '吠', 303: '闻', 304: '皆', 305: '舞', 306: '零', 307: '时', 308: '只', 309: '说', 310: '干', 311: '我', 312: '置', 313: '放', 314: '才', 315: '渡', 316: '辛', 317: '专', 318: '昭', 319: '机', 320: '钩', 321: '陵', 322: '巫', 323: '荷', 324: '昊', 325: '辈', 326: '灭', 327: '已', 328: '、', 329: '殒', 330: '广', 331: '勾', 332: '控', 333: '英', 334: '龄', 335: '席', 336: '湖', 337: '凤', 338: '傥', 339: '莫', 340: '埃', 341: '夕', 342: '行', 343: '低', 344: '故', 345: '邯', 346: '山', 347: '诺', 348: '在', 349: '手', 350: '树', 351: '与', 352: '迷', 353: '赦', 354: '贵', 355: '尝', 356: '三', 357: '义', 358: '肥', 359: '众', 360: '圆', 361: '托', 362: '著', 363: '秩', 364: '阁', 365: '腾', 366: '星', 367: '聚', 368: '者', 369: '匈', 370: '掬', 371: '事', 372: '穷', 373: '帆', 374: '揽', 375: '存', 376: '公', 377: '襟', 378: '茫', 379: '歧', 380: '紫', 381: '预', 382: '平', 383: '忽', 384: '烦', 385: '侬', 386: '中', 387: '急', 388: '兀', 389: '驾', 390: '九', 391: '而', 392: '仰', 393: '阳', 394: '骑', 395: '营', 396: '师', 397: '坠', 398: '任', 399: '瀑', 400: '陶', 401: '尽', 402: '聊', 403: '桑', 404: '作', 405: '漫', 406: '列', 407: '兴', 408: '仍', 409: '楠', 410: '妆', ...

# %%
len(sentences)
# Out:
# 2955

# %%
n_chars
# Out:
# 1472

# %%
sentences[:10]
# Out:
# ['将进酒君不见黄河之水天上来，奔流到海不复',
#  '君不见黄河之水天上来，奔流到海不复回。君',
#  '黄河之水天上来，奔流到海不复回。君不见高',
#  '水天上来，奔流到海不复回。君不见高堂明镜',
#  '来，奔流到海不复回。君不见高堂明镜悲白发',
#  '流到海不复回。君不见高堂明镜悲白发，朝如',
#  '不复回。君不见高堂明镜悲白发，朝如青丝暮',
#  '。君不见高堂明镜悲白发，朝如青丝暮成雪。',
#  '见高堂明镜悲白发，朝如青丝暮成雪。人生得',
#  '明镜悲白发，朝如青丝暮成雪。人生得意须尽']

# %% [markdown]
# ## one-hot编码

# %%
# 将所有句子中的字符转换为独热编码的形式
import numpy as np
import torch
X_train = torch.zeros((len(sentences), maxlen, len(chars)), dtype=torch.float32)
y_train = torch.zeros((len(sentences), len(chars)), dtype=torch.float32)

for i, sentence in enumerate(sentences):
    for j, char in enumerate(sentence):
        X_train[i, j, char_indices[char]] = 1
    y_train[i, char_indices[next_chars[i]]] = 1

# %%
X_train[0][0]
# Out:
# tensor([0., 0., 0.,  ..., 0., 0., 0.])

# %%
len(X_train[0][0])
# Out:
# 1472

# %% [markdown]
# # LSTM建模

# %%
class RNNModel(nn.Module):
  def __init__(self, input_size, hidden_size, output_size):
      super().__init__()
      self.rnn = nn.RNN(input_size, hidden_size, batch_first=True)
      self.linear = nn.Linear(hidden_size, output_size)
      self.fc = nn.Linear(hidden_size, output_size)

  def forward(self, x):
      out,_ = self.rnn(x)
      out = out[:, -1, :]
      return self.fc(out)

class LSTMModel(nn.Module):
  def __init__(self, input_size, hidden_size, output_size):
      super().__init__()
      self.rnn = nn.LSTM(input_size, hidden_size, batch_first=True)
      self.fc = nn.Linear(hidden_size, output_size)

  def forward(self, x):
      out,_ = self.rnn(x)
      out = out[:, -1, :]
      return self.fc(out)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
model = LSTMModel(len(chars), 128, len(chars)).to(device)
X_train = X_train.to(device)
y_train = y_train.to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.01)

num_epochs = 100
for epoch in range(num_epochs):
    optimizer.zero_grad()
    output = model(X_train.float())
    loss = criterion(output, y_train.argmax(dim=1).to(device))
    loss.backward()
    optimizer.step()
    print(f'Epoch: [{epoch+1}], Loss: {loss.item():.4f}')
# Out:
# Epoch: [1], Loss: 7.2856
# Epoch: [2], Loss: 7.1894
# Epoch: [3], Loss: 6.6581
# Epoch: [4], Loss: 6.2853
# Epoch: [5], Loss: 6.1330
# Epoch: [6], Loss: 6.0480
# Epoch: [7], Loss: 6.0314
# Epoch: [8], Loss: 6.0198
# Epoch: [9], Loss: 6.0217
# Epoch: [10], Loss: 6.0116
# Epoch: [11], Loss: 5.9864
# Epoch: [12], Loss: 5.9647
# Epoch: [13], Loss: 5.9564
# Epoch: [14], Loss: 5.9560
# Epoch: [15], Loss: 5.9539
# Epoch: [16], Loss: 5.9449
# Epoch: [17], Loss: 5.9305
# Epoch: [18], Loss: 5.9158
# Epoch: [19], Loss: 5.9031
# Epoch: [20], Loss: 5.8910
# Epoch: [21], Loss: 5.8770
# Epoch: [22], Loss: 5.8587
# Epoch: [23], Loss: 5.8363
# Epoch: [24], Loss: 5.8107
# Epoch: [25], Loss: 5.7818
# Epoch: [26], Loss: 5.7491
# Epoch: [27], Loss: 5.7140
# Epoch: [28], Loss: 5.6745
# Epoch: [29], Loss: 5.6337
# Epoch: [30], Loss: 5.5988
# Epoch: [31], Loss: 5.5415
# Epoch: [32], Loss: 5.4848
# Epoch: [33], Loss: 5.4320
# Epoch: [34], Loss: 5.3580
# Epoch: [35], Loss: 5.2921
# Epoch: [36], Loss: 5.2180
# Epoch: [37], Loss: 5.1322
# Epoch: [38], Loss: 5.1483
# Epoch: [39], Loss: 5.0832
# Epoch: [40], Loss: 4.9857
# Epoch: [41], Loss: 4.8641
# Epoch: [42], Loss: 4.7629
# Epoch: [43], Loss: 4.6670
# Epoch: [44], Loss: 4.5831
# Epoch: [45], Loss: 4.4921
# Epoch: [46], Loss: 4.3710
# Epoch: [47], Loss: 4.2447
# Epoch: [48], Loss: 4.1342
# Epoch: [49], Loss: 3.9930
# Epoch: [50], Loss: 3.8739
# Epoch: [51], Loss: 3.7606
# Epoch: [52], Loss: 3.6133
# Epoch: [53], Loss: 3.4625
# Epoch: [54], Loss: 3.3063
# Epoch: [55], Loss: 3.1764
# Epoch: [56], Loss: 3.0456
# Epoch: [57], Loss: 2.9391
# Epoch: [58], Loss: 2.8097
# Epoch: [59], Loss: 2.5960
# Epoch: [60], Loss: 2.5285
# Epoch: [61], Loss: 2.3606
# Epoch: [62], Loss: 2.2068
# Epoch: [63], Loss: 2.0960
# Epoch: [64], Loss: 1.9591
# Epoch: [65], Loss: 1.8392
# Epoch: [66], Loss: 1.7180
# Epoch: [67], Loss: 1.6117
# Epoch: [68], Loss: 1.5169
# Epoch: [69], Loss: 1.4362
# Epoch: [70], Loss: 1.3225
# Epoch: [71], Loss: 1.2242
# Epoch: [72], Loss: 1.1474
# Epoch: [73], Loss: 1.0647
# Epoch: [74], Loss: 0.9763
# Epoch: [75], Loss: 0.9225
# Epoch: [76], Loss: 0.8757
# Epoch: [77], Loss: 0.7924
# Epoch: [78], Loss: 0.7230
# Epoch: [79], Loss: 0.6636
# Epoch: [80], Loss: 0.6134
# Epoch: [81], Loss: 0.5607
# Epoch: [82], Loss: 0.5104
# Epoch: [83], Loss: 0.4654
# Epoch: [84], Loss: 0.4216
# Epoch: [85], Loss: 0.3833
# Epoch: [86], Loss: 0.3460
# Epoch: [87], Loss: 0.3163
# Epoch: [88], Loss: 0.2841
# Epoch: [89], Loss: 0.2578
# Epoch: [90], Loss: 0.2312
# Epoch: [91], Loss: 0.2094
# Epoch: [92], Loss: 0.1881
# Epoch: [93], Loss: 0.1710
# Epoch: [94], Loss: 0.1545
# Epoch: [95], Loss: 0.1405
# Epoch: [96], Loss: 0.1263
# Epoch: [97], Loss: 0.1159
# Epoch: [98], Loss: 0.1047
# Epoch: [99], Loss: 0.0957
# Epoch: [100], Loss: 0.0883

# %%
def sample(preds, temperature=1.0):
    preds = torch.softmax(preds / temperature, dim=-1)
    preds = preds.detach().cpu().numpy()
    return np.random.choice(len(preds), p=preds)

def generate_text(length, diversity):
    start_index = random.randint(0, len(content) - maxlen - 1)
    sentence = content[start_index : start_index + maxlen]
    generate = ""
    for i in range(length):
        x_pred = torch.zeros((1, maxlen, len(chars)), dtype=torch.float32).to(device)
        for t, char in enumerate(sentence):
            x_pred[0, t, char_indices[char]] = 1
        preds = model(x_pred)[0]
        next_index = sample(preds, diversity)
        next_char = indices_char[next_index]
        sentence = sentence[1:] + next_char
        generate += next_char
    return generate

# %%
generate_text(24, 0.9)
# Out:
# '抱抱以，窈明飞羽枝水东流流天。坐白·长相天门前。'
